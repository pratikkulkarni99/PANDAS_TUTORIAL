# %%
import pandas as pd   #import
df=pd.read_csv("C:\\Users\\Pratik1\Desktop\\dataset\\data's\\Temperature.csv")
print(df)
df=pd.DataFrame(df) #converted to dataframe 
print(df)
# Out:
#                   datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0      2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1      2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2      2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3      2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4      2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
# ...                    ...         ...         ...            ...         ...
# 45248  2017-11-29 20:00:00         NaN  282.000000            NaN  280.820000
# 45249  2017-11-29 21:00:00         NaN  282.890000            NaN  281.650000
# 45250  2017-11-29 22:00:00         NaN  283.390000            NaN  282.750000
# 45251  2017-11-29 23:00:00         NaN  283.020000            NaN  282.960000
# 45252   2017-11-30 0:00:00         NaN  282.280000            NaN  283.040000
#
# ...

# %%
df.head() #first 5 values
# Out:
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4  2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 0          NaN         NaN         NaN         NaN          NaN  ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2   291.868185  291.533501  293.403141  296.608509   285.154558  ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952  ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345  ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# ...

# %%
df.info()   #getting all datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           45253 non-null  object
#  1   Vancouver          44458 non-null  float64
#  2   Portland           45252 non-null  float64
#  3   San Francisco      44460 non-null  float64
#  4   Seattle            45250 non-null  float64
#  5   Los Angeles        45250 non-null  float64
#  6   San Diego          45252 non-null  float64
#  7   Las Vegas          45252 non-null  float64
#  8   Phoenix            45250 non-null  float64
#  9   Albuquerque        45252 non-null  float64
#  10  Denver             45252 non-null  float64
#  11  San Antonio        45252 non-null  float64
#  12  Dallas             45249 non-null  float64
#  13  Houston            45250 non-null  float64
#  14  Kansas City        45252 non-null  float64
# ...

# %%
df.corr()        #checking a linear relation between parameters
# Out:
#                    Vancouver  Portland  San Francisco   Seattle  Los Angeles  \
# Vancouver           1.000000  0.921269       0.730196  0.953015     0.706046
# Portland            0.921269  1.000000       0.778911  0.961838     0.750034
# San Francisco       0.730196  0.778911       1.000000  0.765497     0.845648
# Seattle             0.953015  0.961838       0.765497  1.000000     0.732336
# Los Angeles         0.706046  0.750034       0.845648  0.732336     1.000000
# San Diego           0.666484  0.703792       0.800986  0.689777     0.960359
# Las Vegas           0.820860  0.818120       0.785541  0.806900     0.836604
# Phoenix             0.823205  0.816417       0.808401  0.813503     0.857805
# Albuquerque         0.778270  0.767923       0.741920  0.766645     0.765371
# Denver              0.768836  0.740145       0.712174  0.750456     0.756583
# San Antonio         0.722126  0.705239       0.673104  0.707697     0.668398
# ...

# %%
df['Dallas'].value_counts()
#checking how many different classes are present in a column
# Out:
# 293.563000    193
# 296.150000     77
# 299.150000     65
# 290.370000     58
# 301.150000     58
#              ...
# 290.762500      1
# 300.162667      1
# 297.979333      1
# 291.891000      1
# 289.212667      1
# Name: Dallas, Length: 15720, dtype: int64

# %%
df[df['Dallas']>=300]  #values greater than 300
# Out:
#                   datetime  Vancouver  Portland  San Francisco  Seattle  \
# 31     2012-10-02 19:00:00     289.51    292.73         300.03   292.06
# 32     2012-10-02 20:00:00     289.67    295.57         301.07   293.68
# 33     2012-10-02 21:00:00     290.29    297.94         302.29   295.32
# 34     2012-10-02 22:00:00     291.09    300.00         304.70   295.18
# 35     2012-10-02 23:00:00     291.18    300.55         304.86   296.11
# ...                    ...        ...       ...            ...      ...
# 44677   2017-11-06 1:00:00        NaN    281.01            NaN   275.04
# 44960  2017-11-17 20:00:00        NaN    282.13            NaN   281.15
# 44961  2017-11-17 21:00:00        NaN    282.89            NaN   282.05
# 44962  2017-11-17 22:00:00        NaN    283.72            NaN   281.94
# 44963  2017-11-17 23:00:00        NaN    283.39            NaN   281.81
#
#        Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
from io import StringIO,BytesIO
data=('col1,col2,col3\n'
                'x,y,1\n'
                'a,b,2\n'
                'c,d,3')
type(data)
pd.read_csv(StringIO(data))
# Out:
#   col1 col2  col3
# 0    x    y     1
# 1    a    b     2
# 2    c    d     3

# %%
help(StringIO)
# Out:
# Help on class StringIO in module io:
#
# class StringIO(_TextIOBase)
#  |  StringIO(initial_value='', newline='\n')
#  |
#  |  Text I/O implementation using an in-memory buffer.
#  |
#  |  The initial_value argument sets the value of object.  The newline
#  |  argument is like the one of TextIOWrapper's constructor.
#  |
#  |  Method resolution order:
#  |      StringIO
#  |      _TextIOBase
#  |      _IOBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getstate__(...)
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __setstate__(...)
#  |
#  |  close(self, /)
#  |      Close the IO object.
#  |
#  |      Attempting any further operation after the object is closed
#  |      will raise a ValueError.
#  |
#  |      This method has no effect if the file is already closed.
#  |
#  |  getvalue(self, /)
# ...

# %%
#getting all parameters as object
df=pd.read_csv(StringIO(data),dtype='object',usecols=['col1','col3'])
print(df)
# Out:
#   col1 col3
# 0    x    1
# 1    a    2
# 2    c    3

# %%
df['col1'][2]
# Out:
# 'c'

# %%
df.to_csv("Test.csv")

# %%
dt=('index,a,b,c\n'
        '4,apple,bat,7.9\n'
         '8,Orange,cow,10')
print(dt)
pd.read_csv(StringIO(dt),index_col=0)
# Out:
# index,a,b,c
# 4,apple,bat,7.9
# 8,Orange,cow,10
#             a    b     c
# index
# 4       apple  bat   7.9
# 8      Orange  cow  10.0

# %%
dt=('index,a,b,c\n'
        '4,apple,bat,7.9\n'
         '8,Orange,cow,10')
print(dt)
pd.read_csv(StringIO(dt),index_col=False)#by applying this we get to know index new column added
# Out:
# index,a,b,c
# 4,apple,bat,7.9
# 8,Orange,cow,10
#    index       a    b     c
# 0      4   apple  bat   7.9
# 1      8  Orange  cow  10.0

# %%
dt=('index,a,b,c\n'
        '4,apple,bat,7.9\n'
         '8,Orange,cow,10')
print(dt)
pd.read_csv(StringIO(dt),usecols=['b','c'],index_col=False) #use of b&c columns
# Out:
# index,a,b,c
# 4,apple,bat,7.9
# 8,Orange,cow,10
#      b     c
# 0  bat   7.9
# 1  cow  10.0

# %%
data='a,b\n"hello, \\"bob\\",nice to see you",5'
pd.read_csv(StringIO(data),escapechar='\\')
# Out:
#                               a  b
# 0  hello, "bob",nice to see you  5

# %% [markdown]
# ## Reading a JSON

# %%
D='{"emp_name":"R","email":"prk@yahoo.com","job":[{"Title1":"Team-lead","Title2":"Sr.DS"}]}'
pd.read_json(D)
#json file and nested json
# Out:
#   emp_name          email                                         job
# 0        R  prk@yahoo.com  {'Title1': 'Team-lead', 'Title2': 'Sr.DS'}
